# %%
import os  # 用於文件操作
import cv2  # 用於影像處理
import math  # 用於數學運算
import numpy as np  # 用於數值運算
import pandas as pd  # 用於數據處理
import joblib  # 用於保存和加載資料縮放器
import matplotlib.pyplot as plt  # 用於繪圖
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from datetime import datetime  # 用於時間操作
from sklearn.preprocessing import MinMaxScaler  # 用於資料縮放

import tensorflow as tf  # 用於構建模型
from tensorflow.keras import backend as K  # 用於自定義損失函數

# %%
SPLIT_DATA_MODE = 'month'  # 數據分割模式 sequence or month
LATITUDE = 'Latitude'
LONGITUDE = 'Longitude'
WINDOW_SIZE = 3
STEP_SIZE = 2
# CELL_DATASET_PATH = r'E:\YuCheng\cell_data_processed\cells'
CELL_DATASET_PATH = r'H:\cell_data_processed\cells'
SCALER_PATH = rf'config\{SPLIT_DATA_MODE}\lstm_multitask_scaler.gz'
MODEL_PATH = rf'weights\{SPLIT_DATA_MODE}\non_cumulative_diff\lstm_multitask\lstm_mt_diff3-2_e19v0.0006'
# weights\month\non_cumulative_diff\lstm_multitask\lstm_mt_diff2-2_e04v0.0007

# %%
# ============= 均方根誤差 =============
def rmse(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# ============= 計算差分資料 =============
def data_diff_processing(data):
    data_filtered = data[['Latitude', 'Longitude']]
    data_diff = data_filtered.diff().dropna().reset_index(drop=True)
    return data_diff

# ============= 讀取模型 =============
def load_model(model_path: str, custom_objects: dict = None) -> tf.keras.models.Model:
    if custom_objects is None:
        return tf.keras.models.load_model(model_path)
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# ============= 讀取scaler =============
def load_scaler(scaler_path: str) -> joblib.load:
    return joblib.load(scaler_path)

# ============= 讀取資料 =============
def read_data(start_date: str, end_date: str, scaler: MinMaxScaler) -> tuple:
    start_date = datetime.strptime(start_date, '%Y-%m-%d').strftime('%Y%m%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d').strftime('%Y%m%d')
    print(f'個案日期 {start_date} ~ {end_date}')

    cell_files = sorted(os.listdir(CELL_DATASET_PATH))

    # 原始數值資料，每一個元素是一個DataFrame，每一個DataFrame是一個cell的數值序列
    dataset = []
    # 差分數值資料，每一個元素是一個DataFrame，每一個DataFrame是一個cell的差分數值序列
    diff_dataset = []
    # LSTM 輸入資料(差分數值資料)
    lstm_input_dataset = []

    for cell_file in cell_files:
        cell_file_path = os.path.join(CELL_DATASET_PATH, cell_file)

        target_date = datetime.strptime(
            cell_file.split('-')[0], '%Y%m%d').strftime('%Y%m%d')

        if not (start_date <= target_date <= end_date):
            continue

        # ============= 處理單一個數值序列資料 =============
        # 讀取CSV數據並計算差值
        cell_data = pd.read_csv(cell_file_path, encoding='utf-8',
                                dtype={'fileName': str, 'day': str, 'time': str})
        
        # print(len(cell_data), cell_file_path)
        if len(cell_data) < (WINDOW_SIZE + STEP_SIZE) + 1:
            # 資料不夠長，無法進行滑動窗口處理(至少需要 window_size + step_size + 1 筆資料)
            print(f"資料長度不足，跳過 {cell_file_path}")
            continue

        # 計算經緯度差分
        data_diff = cell_data[[LATITUDE, LONGITUDE]
                              ].diff().dropna().reset_index(drop=True)

        # 提取經度和緯度差值
        lat_diff = cell_data[LATITUDE].diff().dropna().reset_index(drop=True)
        lng_diff = cell_data[LONGITUDE].diff().dropna().reset_index(drop=True)

        combined_data = np.vstack([lat_diff.values, lng_diff.values]).T  # 經緯度差異合併

        # 使用scaler對資料進行縮放
        scaled_data_diff = scaler.transform(combined_data)

        dataset.append(cell_data)
        diff_dataset.append(data_diff)
        lstm_input_dataset.append(scaled_data_diff)

    return (dataset, diff_dataset, lstm_input_dataset)

# %%
# ============= 預測路徑 =============
def predict_path(model: tf.keras.models.Model, dataset_components: tuple) -> np.array:
    dataset, diff_dataset, lstm_input_dataset = dataset_components

    diff_pred_dict = {}  # 用經緯度差分預測結果
    diff_true_dict = {}  # 用經緯度差分真實結果

    for i, data in enumerate(dataset):

        diff_pred = []  # [(lat_diff, lng_diff), (lat_diff, lng_diff), ...]
        diff_true = []  # [(lat_diff, lng_diff), (lat_diff, lng_diff), ...]

        for j in range(0, len(lstm_input_dataset[i]) - WINDOW_SIZE - 1, 1):
            # 準備 LSTM 和 ConvLSTM 輸入數據
            lstm_input = np.expand_dims(
                np.array(lstm_input_dataset[i][j: j+WINDOW_SIZE], dtype=np.float32), axis=0)
            
            input_data = lstm_input

            # 預測經緯度差分
            lat_pred, lng_pred = model.predict(input_data)

            # 獲取真實經緯度差分
            lat_d3 = diff_dataset[i][LATITUDE].values[j + WINDOW_SIZE]
            lat_d4 = diff_dataset[i][LATITUDE].values[j + WINDOW_SIZE + 1]
            lng_d3 = diff_dataset[i][LONGITUDE].values[j + WINDOW_SIZE]
            lng_d4 = diff_dataset[i][LONGITUDE].values[j + WINDOW_SIZE + 1]

            true_lat = np.array([lat_d3, lat_d4], dtype=np.float32)
            true_lng = np.array([lng_d3, lng_d4], dtype=np.float32)

            diff_pred.append((np.squeeze(lat_pred), np.squeeze(lng_pred)))
            diff_true.append((true_lat, true_lng))

        diff_pred_dict[i] = diff_pred
        diff_true_dict[i] = diff_true

    print(f'預測資料長度: {len(diff_pred_dict)}, 真實資料長度: {len(diff_true_dict)}')
    return dataset, diff_pred_dict, diff_true_dict

# %%
import math
from haversine import haversine

# ============= 計算誤差(公里) =============
def calculate_mae_distance(lat_mae: float, lon_mae: float, latitude: float = 25.071182):
    lat_km = lat_mae * 111
    lon_km = lon_mae * 111 * math.cos(math.radians(latitude))
    return math.sqrt(lat_km**2 + lon_km**2)

# ============= 評估主函式（輸入2預測2，累積差分 y） =============
def evaluate(dataset: list, pred_dict: dict) -> None:
    # ===== 還原位置誤差（預測累積差加回基準位置） =====
    lat_errors = []
    lng_errors = []
    distances = []

    # 分開統計 t+1 / t+2 的誤差
    lat_errors_1, lng_errors_1, dist_1 = [], [], []
    lat_errors_2, lng_errors_2, dist_2 = [], [], []

    for i, data in enumerate(dataset):
        latitudes = np.array(data[LATITUDE])
        longitudes = np.array(data[LONGITUDE])

        for j, diff_pred in enumerate(pred_dict[i]):
            base_lat = latitudes[j + WINDOW_SIZE]
            base_lng = longitudes[j + WINDOW_SIZE]

            pred_lat1 = base_lat + diff_pred[0][0]
            pred_lat2 = pred_lat1 + diff_pred[0][1]
            pred_lng1 = base_lng + diff_pred[1][0]
            pred_lng2 = pred_lng1 + diff_pred[1][1]

            real_lat1 = latitudes[j + WINDOW_SIZE + 1]
            real_lat2 = latitudes[j + WINDOW_SIZE + 2]
            real_lng1 = longitudes[j + WINDOW_SIZE + 1]
            real_lng2 = longitudes[j + WINDOW_SIZE + 2]

            # 全體誤差
            lat_errors.extend([real_lat1 - pred_lat1, real_lat2 - pred_lat2])
            lng_errors.extend([real_lng1 - pred_lng1, real_lng2 - pred_lng2])
            distances.extend([
                haversine((real_lat1, real_lng1), (pred_lat1, pred_lng1)),
                haversine((real_lat2, real_lng2), (pred_lat2, pred_lng2))
            ])

            # t+1
            lat_errors_1.append(real_lat1 - pred_lat1)
            lng_errors_1.append(real_lng1 - pred_lng1)
            dist_1.append(haversine((real_lat1, real_lng1), (pred_lat1, pred_lng1)))

            # t+2
            lat_errors_2.append(real_lat2 - pred_lat2)
            lng_errors_2.append(real_lng2 - pred_lng2)
            dist_2.append(haversine((real_lat2, real_lng2), (pred_lat2, pred_lng2)))

    # ========= 全部預測誤差 =========
    lat_mae_pos = np.mean(np.abs(lat_errors))
    lng_mae_pos = np.mean(np.abs(lng_errors))
    lat_mse_pos = np.mean(np.square(lat_errors))
    lng_mse_pos = np.mean(np.square(lng_errors))
    lat_rmse_pos = np.sqrt(lat_mse_pos)
    lng_rmse_pos = np.sqrt(lng_mse_pos)
    avg_distance = np.mean(distances)

    print("=== 經緯度位置（還原後）總體評估 ===")
    print(f'Latitude MSE: {lat_mse_pos:.6f} 度')
    print(f'Longitude MSE: {lng_mse_pos:.6f} 度')
    print(f'Latitude MAE: {lat_mae_pos:.6f} 度')
    print(f'Longitude MAE: {lng_mae_pos:.6f} 度')
    print(f'Latitude RMSE: {lat_rmse_pos:.6f}')
    print(f'Longitude RMSE: {lng_rmse_pos:.6f}')
    print(f'Average Haversine distance error: {avg_distance:.3f} km\n')

    # ========= t+1 預測誤差 =========
    lat1_mae = np.mean(np.abs(lat_errors_1))
    lng1_mae = np.mean(np.abs(lng_errors_1))
    lat1_mse = np.mean(np.square(lat_errors_1))
    lng1_mse = np.mean(np.square(lng_errors_1))
    lat1_rmse = np.sqrt(np.mean(np.square(lat_errors_1)))
    lng1_rmse = np.sqrt(np.mean(np.square(lng_errors_1)))
    dist1_avg = np.mean(dist_1)

    print("=== 第一步預測 (t+1) 評估 ===")
    print(f'Latitude MSE: {lat1_mse:.6f} 度')
    print(f'Longitude MSE: {lng1_mse:.6f} 度')
    print(f'Latitude MAE: {lat1_mae:.6f} 度')
    print(f'Longitude MAE: {lng1_mae:.6f} 度')
    print(f'Latitude RMSE: {lat1_rmse:.6f}')
    print(f'Longitude RMSE: {lng1_rmse:.6f}')
    print(f'Average Haversine distance error: {dist1_avg:.3f} km\n')

    # ========= t+2 預測誤差 =========
    lat2_mae = np.mean(np.abs(lat_errors_2))
    lng2_mae = np.mean(np.abs(lng_errors_2))
    lat2_mse = np.mean(np.square(lat_errors_2))
    lng2_mse = np.mean(np.square(lng_errors_2))
    lat2_rmse = np.sqrt(np.mean(np.square(lat_errors_2)))
    lng2_rmse = np.sqrt(np.mean(np.square(lng_errors_2)))
    dist2_avg = np.mean(dist_2)

    print("=== 第二步預測 (t+2) 評估 ===")
    print(f'Latitude MSE: {lat2_mse:.6f} 度')
    print(f'Longitude MSE: {lng2_mse:.6f} 度')
    print(f'Latitude MAE: {lat2_mae:.6f} 度')
    print(f'Longitude MAE: {lng2_mae:.6f} 度')
    print(f'Latitude RMSE: {lat2_rmse:.6f}')
    print(f'Longitude RMSE: {lng2_rmse:.6f}')
    print(f'Average Haversine distance error: {dist2_avg:.3f} km')

# %%
# ============= 繪製路徑 =============
def plot_path(dataset: list, diff_pred_dict: dict) -> None:
    fig = plt.figure(figsize=(10, 6))
    ax = plt.axes(projection=ccrs.PlateCarree())  # 經緯度座標系

    # =================== 統計所有經緯度的最大最小值 ===================
    all_lats = []
    all_lngs = []

    for i, data in enumerate(dataset):
        lats = np.array(data[LATITUDE])
        lngs = np.array(data[LONGITUDE])
        all_lats.extend(lats)
        all_lngs.extend(lngs)

    min_lat, max_lat = min(all_lats), max(all_lats)
    min_lng, max_lng = min(all_lngs), max(all_lngs)

    # =================== 繪圖開始 ===================
    ax.coastlines(resolution='10m', linewidth=1)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5)
    ax.add_feature(cfeature.LAND, facecolor='lightgray')

    # 設定經緯度邊界（可根據實際資料調整）
    lat_buffer = (max_lat - min_lat) * 0.05
    lng_buffer = (max_lng - min_lng) * 0.05
    ax.set_extent([
        min_lng - lng_buffer, max_lng + lng_buffer,
        min_lat - lat_buffer, max_lat + lat_buffer
    ], crs=ccrs.PlateCarree())
    ax.set_extent([120.2320782, 124.1435858, 22.6607914, 26])

    # =================== 畫實際與預測軌跡 ===================
    for i, data in enumerate(dataset):
        latitudes = np.array(data[LATITUDE])
        longitudes = np.array(data[LONGITUDE])

        # 預測位置還原（兩步）
        pred_lat1_list = []
        pred_lng1_list = []
        pred_lat2_list = []
        pred_lng2_list = []

        for j, diff_pred in enumerate(diff_pred_dict[i]):
            base_lat = latitudes[j + WINDOW_SIZE]
            base_lng = longitudes[j + WINDOW_SIZE]

            # diff_pred: [[lat_t+1, lat_t+2], [lng_t+1, lng_t+2]]
            pred_lat1 = base_lat + diff_pred[0][0]
            pred_lat2 = pred_lat1 + diff_pred[0][1]
            pred_lng1 = base_lng + diff_pred[1][0]
            pred_lng2 = pred_lng1 + diff_pred[1][1]

            pred_lat1_list.append(pred_lat1)
            pred_lat2_list.append(pred_lat2)
            pred_lng1_list.append(pred_lng1)
            pred_lng2_list.append(pred_lng2)

        # 畫實際路徑與預測路徑
        plt.plot(longitudes, latitudes, marker='o',
                 markersize=1.5, color='#1f77b4', linewidth=0.5)  # 實際
        plt.plot(pred_lng1_list, pred_lat1_list, marker='o',
                 markersize=1.5, color='#ff7f0e', linewidth=0.5)  # 預測 t+1
        plt.plot(pred_lng2_list, pred_lat2_list, marker='o',
                 markersize=1.5, color='#2ca02c', linewidth=0.5)  # 預測 t+2

    plt.legend(['Ground Truth', 'Prediction t+1', 'Prediction t+2'])
    plt.title(f'LSTM Multitask Prediction ({SPLIT_DATA_MODE})')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.tight_layout()
    # plt.savefig('result/prediction_result.png')
    plt.show()

# %%
# 測試集資料範圍: 2022-07-01 ~ 2022-08-31 可按照需求調整
# start_date = '2022-10-04'
# end_date = '2022-10-04'
# start_date = '2022-12-06'
# end_date = '2022-12-06'
# 時序切割、月份切割共同資料集範圍
start_date = '2022-11-27'
end_date = '2022-11-29'

# 2021-05-30 04 ~ 10 UTC 梅雨鋒面
start_date = '2022-05-30'
end_date = '2022-05-30' 

# 讀取模型
model = load_model(model_path=MODEL_PATH, custom_objects={'rmse': rmse})
# 列印模型結構
# print(model.summary())

print('--------------模型讀取成功--------------')

# 讀取資料縮放器
scaler = load_scaler(scaler_path=SCALER_PATH)

# 讀取資料(原始數值資料，差分數值資料，LSTM輸入數據，ConvLSTM輸入數據)
dataset_components = read_data(
    start_date=start_date,  
    end_date=end_date,  
    scaler=scaler
)

# 預測差分路徑
dataset, diff_pred_dict, diff_true_dict = predict_path(
    model=model, dataset_components=dataset_components)

print(diff_pred_dict)
print(diff_true_dict)

# 評估模型
evaluate(dataset, diff_pred_dict)

# 繪製預測路徑與真實路徑
plot_path(dataset, diff_pred_dict)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# --------------模型讀取成功--------------
# 個案日期 20220530 ~ 20220530
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-082457_4_082457.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-083053_7_083053.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-085435_7_085435.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-090626_15_090626.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-091222_11_091222.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-091818_17_091818.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-100145_17_100145.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-100742_29_100742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-100742_51_100742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-100742_52_100742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-100742_54_100742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-100742_61_100742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-100742_64_100742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-101338_67_101338.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-101934_75_101934.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-103125_35_103125.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-103722_95_103722.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-104914_9_104914.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-105510_20_105510.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-110704_13_110704.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-110704_41_110704.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-110704_45_110704.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-111301_52_111301.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-111301_59_111301.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-111857_10_111857.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-111857_68_111857.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-112454_69_112454.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-113646_4_113646.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-113646_50_113646.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-113646_5_113646.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-113646_83_113646.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-113646_87_113646.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-113646_91_113646.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-114244_7_114244.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-114840_11_114840.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-114840_33_114840.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-115437_39_115437.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-120033_55_120033.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-120033_66_120033.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-120033_73_120033.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-120629_76_120629.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-121225_2_121225.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-121225_83_121225.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-121225_96_121225.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-121821_7_121821.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-122418_100_122418.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-122418_20_122418.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-122418_25_122418.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-122418_85_122418.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-122418_98_122418.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-123013_41_123013.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-123609_60_123609.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-123609_65_123609.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-124205_1_124205.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-124205_81_124205.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-124205_89_124205.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-124205_92_124205.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-124205_96_124205.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-124802_13_124802.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-124802_4_124802.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-124802_67_124802.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-124802_6_124802.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-125359_12_125359.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-125359_14_125359.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-125359_21_125359.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-125954_36_125954.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-125954_40_125954.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-125954_42_125954.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-131743_100_131743.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-131743_83_131743.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-131743_95_131743.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-132935_12_132935.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-132935_18_132935.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-132935_4_132935.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-134724_22_134724.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-134724_37_134724.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-135321_46_135321.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-135918_51_135918.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-135918_54_135918.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-140514_60_140514.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-140514_71_140514.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-140514_78_140514.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-140514_97_140514.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-141111_11_141111.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-141111_88_141111.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-141707_100_141707.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-142304_51_142304.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-143459_10_143459.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-143459_16_143459.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-143459_20_143459.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-144055_30_144055.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-144055_33_144055.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-144652_37_144652.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-145844_20_145844.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-145844_28_145844.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-145844_70_145844.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-150441_83_150441.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-151037_10_151037.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-151037_6_151037.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-151634_17_151634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-151634_24_151634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-151634_37_151634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-151634_38_151634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-151634_39_151634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-152232_4_152232.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-152827_53_152827.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-152827_60_152827.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-153424_33_153424.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-153424_73_153424.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-153424_84_153424.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-154617_20_154617.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-154617_26_154617.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-154617_31_154617.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-154617_78_154617.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-155213_51_155213.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-155809_23_155809.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-155809_76_155809.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-160407_46_160407.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-160407_92_160407.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-160407_94_160407.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-161004_3_161004.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-161004_68_161004.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-161004_6_161004.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-161600_20_161600.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-162155_33_162155.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-163945_71_163945.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-164542_2_164542.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-165138_16_165138.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-165734_30_165734.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-165734_33_165734.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-170331_42_170331.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-170928_50_170928.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-171525_56_171525.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-172120_33_172120.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-172717_72_172717.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-174711_65_174711.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-174711_95_174711.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-175308_55_175308.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-175905_33_175905.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-180503_11_180503.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-180503_8_180503.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-183446_12_183446.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-183446_14_183446.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-183446_1_183446.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-183446_7_183446.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-183446_9_183446.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-185832_41_185832.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-190429_27_190429.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-192219_64_192219.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-192817_27_192817.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-193413_53_193413.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-194605_34_194605.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-195758_89_195758.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-200952_96_200952.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-201548_4_201548.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-201548_67_201548.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-203937_14_203937.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-203937_16_203937.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-210324_85_210324.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-210921_24_210921.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-210921_29_210921.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-212115_44_212115.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-212711_46_212711.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-212711_47_212711.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-215058_30_215058.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-215655_46_215655.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-215655_72_215655.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-215655_73_215655.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-215655_75_215655.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-220252_44_220252.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-220848_81_220848.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-221445_87_221445.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-221445_88_221445.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-222638_93_222638.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-223832_57_223832.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-224428_43_224428.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-224428_6_224428.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-224428_7_224428.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-225621_8_225621.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-230816_20_230816.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-230816_95_230816.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-231412_25_231412.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-231412_26_231412.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-231412_27_231412.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-231412_30_231412.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-231412_31_231412.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-232009_32_232009.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-233203_39_233203.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-233203_41_233203.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-234357_48_234357.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-234954_63_234954.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-235550_63_235550.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20220530-235550_71_235550.csv
# 1/1 [==============================] - 1s 739ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# ...
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 預測資料長度: 194, 真實資料長度: 194
# {0: [(array([-0.0030366 , -0.00120425], dtype=float32), array([0.0132957 , 0.01400962], dtype=float32)), (array([-0.00633858, -0.00427776], dtype=float32), array([0.00984713, 0.01091035], dtype=float32)), (array([-0.00591548, -0.00370789], dtype=float32), array([0.0134428 , 0.01434543], dtype=float32)), (array([-0.00300926, -0.0009982 ], dtype=float32), array([0.01634225, 0.01696504], dtype=float32)), (array([-1.784401e-03,  8.489750e-05], dtype=float32), array([0.01678314, 0.01729352], dtype=float32)), (array([0.00360776, 0.00487158], dtype=float32), array([0.01882721, 0.01889241], dtype=float32)), (array([0.00598326, 0.00692952], dtype=float32), array([0.01833722, 0.01836471], dtype=float32)), (array([0.00364319, 0.00495858], dtype=float32), array([0.01862493, 0.018788  ], dtype=float32)), (array([-0.00418915, -0.00211318], dtype=float32), array([0.01437787, 0.01516232], dtype=float32)), (array([-0.00806409, -0.00525097], dtype=float32), array([0.01576876, 0.01682496], dtype=float32)), (array([-0.00773468, -0.00504553], dtype=float32), array([0.01538758, 0.01640102], dtype=float32)), (array([-0.00499897, -0.00275493], dtype=float32), array([0.01525225, 0.01604675], dtype=float32)), (array([-0.00371189, -0.00162555], dtype=float32), array([0.01573122, 0.01641993], dtype=float32)), (array([-0.00632828, -0.00383059], dtype=float32), array([0.01587848, 0.01675675], dtype=float32)), (array([-0.00866549, -0.00604725], dtype=float32), array([0.01221351, 0.01338208], dtype=float32)), (array([-0.00843077, -0.00606222], dtype=float32), array([0.00973987, 0.01094257], dtype=float32)), (array([-0.00445829, -0.00251092], dtype=float32), array([0.01287559, 0.01369047], dtype=float32)), (array([-0.0024579 , -0.00053792], dtype=float32), array([0.01625878, 0.01684558], dtype=float32)), (array([0.00051718, 0.00216241], dtype=float32), array([0.01805154, 0.01837848], dtype=float32)), (array([0.00051676, 0.00214467], dtype=float32), array([0.01779981, 0.01812918], dtype=float32)), (array([0.00076277, 0.00237705], dtype=float32), array([0.01808182, 0.01840549], dtype=float32)), (array([-0.00162676,  0.00038583], dtype=float32), array([0.01855968, 0.01902715], dtype=float32))], 1: [(array([-0.00452446, -0.00139033], dtype=float32), array([0.02528808, 0.02580587], dtype=float32)), (array([-0.00473599, -0.00156372], dtype=float32), array([0.02516058, 0.02572469], dtype=float32)), (array([-0.0052021 , -0.00219734], dtype=float32), array([0.02295996, 0.02360565], dtype=float32)), (array([-0.00600203, -0.00287956], dtype=float32), array([0.02299397, 0.02367853], dtype=float32)), (array([-0.00463076, -0.00169386], dtype=float32), array([0.02318821, 0.02378023], dtype=float32)), (array([-0.00471515, -0.00166234], dtype=float32), array([0.02442425, 0.02497634], dtype=float32)), (array([-0.00237662,  0.00028146], dtype=float32), array([0.02422466, 0.02459681], dtype=float32)), (array([-0.00143682,  0.00106208], dtype=float32), array([0.02395941, 0.02427614], dtype=float32)), (array([0.00015144, 0.00239825], dtype=float32), array([0.02377518, 0.02398926], dtype=float32))], 2: [(array([0.00582984, 0.00647927], dtype=float32), array([0.01495563, 0.01506373], dtype=float32)), (array([0.00527067, 0.0056632 ], dtype=float32), array([0.01118359, 0.0113415 ], dtype=float32)), (array([0.01029306, 0.00927213], dtype=float32), array([0.00433587, 0.00439701], dtype=float32)), (array([0.0078537 , 0.00718078], dtype=float32), array([0.0030489, 0.0033867], dtype=float32)), (array([0.00842639, 0.00814617], dtype=float32), array([0.00904847, 0.00914667], dtype=float32)), (array([0.00466478, 0.00519182], dtype=float32), array([0.01233399, 0.0125007 ], dtype=float32)), (array([0.00671748, 0.00669407], dtype=float32), array([0.00866477, 0.0088234 ], dtype=float32)), (array([0.00625065, 0.00601369], dtype=float32), array([0.00507035, 0.00541184], dtype=float32)), (array([0.006099  , 0.00600678], dtype=float32), array([0.00690223, 0.00715411], dtype=float32)), (array([0.00300 ...
# {0: [(array([0.003655, 0.000345], dtype=float32), array([0.011673, 0.031944], dtype=float32)), (array([0.000345, 0.002667], dtype=float32), array([0.031944, 0.01976 ], dtype=float32)), (array([0.002667, 0.008754], dtype=float32), array([0.01976 , 0.016602], dtype=float32)), (array([0.008754, 0.021284], dtype=float32), array([0.016602, 0.047882], dtype=float32)), (array([0.021284, 0.014994], dtype=float32), array([0.047882, 0.013069], dtype=float32)), (array([0.014994, 0.004284], dtype=float32), array([0.013069, 0.026757], dtype=float32)), (array([ 0.004284, -0.01959 ], dtype=float32), array([0.026757, 0.023757], dtype=float32)), (array([-0.01959 , -0.000943], dtype=float32), array([0.023757, 0.02073 ], dtype=float32)), (array([-0.000943,  0.002612], dtype=float32), array([0.02073 , 0.020156], dtype=float32)), (array([ 0.002612, -0.002505], dtype=float32), array([0.020156, 0.019715], dtype=float32)), (array([-0.002505,  0.004257], dtype=float32), array([0.019715, 0.0224  ], dtype=float32)), (array([ 0.004257, -0.011085], dtype=float32), array([0.0224  , 0.026046], dtype=float32)), (array([-0.011085, -0.005648], dtype=float32), array([0.026046, 0.007752], dtype=float32)), (array([-0.005648,  0.004147], dtype=float32), array([0.007752, 0.008934], dtype=float32)), (array([0.004147, 0.000709], dtype=float32), array([0.008934, 0.031212], dtype=float32)), (array([0.000709, 0.003586], dtype=float32), array([0.031212, 0.02362 ], dtype=float32)), (array([0.003586, 0.016071], dtype=float32), array([0.02362 , 0.022293], dtype=float32)), (array([0.016071, 0.001923], dtype=float32), array([0.022293, 0.028984], dtype=float32)), (array([0.001923, 0.007443], dtype=float32), array([0.028984, 0.024758], dtype=float32)), (array([0.007443, 0.002834], dtype=float32), array([0.024758, 0.025749], dtype=float32)), (array([0.002834, 0.004703], dtype=float32), array([0.025749, 0.020088], dtype=float32)), (array([0.004703, 0.016192], dtype=float32), array([0.020088, 0.061409], dtype=float32))], 1: [(array([-0.008494,  0.003815], dtype=float32), array([0.041985, 0.031967], dtype=float32)), (array([ 0.003815, -0.008297], dtype=float32), array([0.031967, 0.043213], dtype=float32)), (array([-0.008297,  0.001055], dtype=float32), array([0.043213, 0.041305], dtype=float32)), (array([0.001055, 0.002468], dtype=float32), array([0.041305, 0.038681], dtype=float32)), (array([0.002468, 0.0056  ], dtype=float32), array([0.038681, 0.039521], dtype=float32)), (array([0.0056  , 0.005398], dtype=float32), array([0.039521, 0.03936 ], dtype=float32)), (array([0.005398, 0.01066 ], dtype=float32), array([0.03936 , 0.036979], dtype=float32)), (array([0.01066 , 0.008402], dtype=float32), array([0.036979, 0.052163], dtype=float32)), (array([0.008402, 0.023597], dtype=float32), array([0.052163, 0.057281], dtype=float32))], 2: [(array([0.013706, 0.032904], dtype=float32), array([ 0.007446, -0.005447], dtype=float32)), (array([0.032904, 0.009784], dtype=float32), array([-0.005447,  0.007736], dtype=float32)), (array([0.009784, 0.018501], dtype=float32), array([0.007736, 0.022613], dtype=float32)), (array([0.018501, 0.011055], dtype=float32), array([0.022613, 0.011414], dtype=float32)), (array([0.011055, 0.018773], dtype=float32), array([0.011414, 0.001953], dtype=float32)), (array([0.018773, 0.014057], dtype=float32), array([0.001953, 0.006554], dtype=float32)), (array([0.014057, 0.012739], dtype=float32), array([0.006554, 0.011772], dtype=float32)), (array([0.012739, 0.008144], dtype=float32), array([0.011772, 0.014106], dtype=float32)), (array([0.008144, 0.011423], dtype=float32), array([0.014106, 0.013665], dtype=float32)), (array([0.011423, 0.022585], dtype=float32), array([0.013665, 0.019363], dtype=float32)), (array([0.022585, 0.029116], dtype=float32), array([0.019363, 0.030693], dtype=float32)), (array([0.029116, 0.01568 ], dtype=float32), array([0.030693, 0.020981], dtype=float32)), (array([0.01568 , 0.016983], dtype=float32), array([0.020981, 0.017509], dtype=float32)), ...
# === 經緯度位置（還原後）總體評估 ===
# Latitude MSE: 0.000435 度
# Longitude MSE: 0.000481 度
# Latitude MAE: 0.016532 度
# Longitude MAE: 0.016538 度
# Latitude RMSE: 0.020845
# Longitude RMSE: 0.021929
# Average Haversine distance error: 2.661 km
#
# === 第一步預測 (t+1) 評估 ===
# Latitude MSE: 0.000209 度
# Longitude MSE: 0.000222 度
# Latitude MAE: 0.011639 度
# Longitude MAE: 0.011487 度
# Latitude RMSE: 0.014444
# Longitude RMSE: 0.014906
# Average Haversine distance error: 1.870 km
#
# === 第二步預測 (t+2) 評估 ===
# Latitude MSE: 0.000660 度
# Longitude MSE: 0.000740 度
# Latitude MAE: 0.021426 度
# Longitude MAE: 0.021589 度
# Latitude RMSE: 0.025698
# Longitude RMSE: 0.027194
# Average Haversine distance error: 3.453 km
