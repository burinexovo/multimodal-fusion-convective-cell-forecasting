# %%
import os  # 用於文件操作
import cv2  # 用於影像處理
import math  # 用於數學運算
import numpy as np  # 用於數值運算
import pandas as pd  # 用於數據處理
import joblib  # 用於保存和加載資料縮放器
import matplotlib.pyplot as plt  # 用於繪圖
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from datetime import datetime  # 用於時間操作
import matplotlib.font_manager as fm

import tensorflow as tf  # 深度學習框架
from tensorflow.keras import backend as K  # 用於自定義損失函數
jheng_hei_b_font = fm.FontProperties(fname=r'fonts\微軟正黑體_粗體.ttc')
jheng_hei_font = fm.FontProperties(fname=r'fonts\微軟正黑體_標準.ttc')

# %%
SPLIT_DATA_MODE = 'month'  # 數據分割模式 sequence or month
HIGHT = WIDTH = 224
LATITUDE = 'Latitude'
LONGITUDE = 'Longitude'
CHANNELS = 1
WINDOW_SIZE = 4
STEP_SIZE = 2
# CELL_DATASET_PATH = r'E:\YuCheng\cell_data_processed\cells'
# RADAR_DATASET_PATH = r'E:\YuCheng\cell_data_processed\radar\grids\global'
CELL_DATASET_PATH = r'H:\cell_data_processed\cells'
RADAR_DATASET_PATH = r'H:\cell_data_processed\radar\grids\global'
MODEL_PATH = rf'weights\{SPLIT_DATA_MODE}\non_cumulative_diff\convlstm_multitask\convlstm_mt_diff4-2_e01v0.0012'
# weights\month\non_cumulative_diff\convlstm_multitask\convlstm_mt_diff2-2_e01v0.0014

# %%
# ============= 均方根誤差 =============
def rmse(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# ============= 計算格點資料差分 =============
def radar_grid_diff_processing(radar_grids: np.ndarray) -> np.ndarray:
    diff_radar_grids = []
    for i in range(len(radar_grids) - 1):
        radar_grid_diff = cv2.absdiff(radar_grids[i + 1], radar_grids[i])
        diff_radar_grids.append(radar_grid_diff)
    return np.expand_dims(np.array(diff_radar_grids), axis=-1)

# ============= 讀取模型 =============
def load_model(model_path: str, custom_objects: dict = None) -> tf.keras.models.Model:
    if custom_objects is None:
        return tf.keras.models.load_model(model_path)
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# ============= 確保雷達與cell資料對應 =============
def get_cell_dataset(radar_folders : list) -> list:
    def make_csv_paths(radar_files : list) -> list:
        return [os.path.basename(f) + '.csv' for f in radar_files]
    
    cell_files = make_csv_paths(radar_folders)
    return cell_files    


# ============= 讀取資料 =============
def read_data(start_date: str, end_date: str) -> tuple:
    print(f'個案日期 {start_date} ~ {end_date}')
    def parse_datetime(date_str: str, is_end: bool = False) -> str:
        try:
            dt = datetime.strptime(date_str, '%Y-%m-%d %H:%M:%S')
            return dt.strftime('%Y%m%d%H%M%S')
        except ValueError:
            dt = datetime.strptime(date_str, '%Y-%m-%d')
            return dt.strftime('%Y%m%d') + ('235959' if is_end else '000000')

    start_date = parse_datetime(start_date, is_end=False)
    end_date = parse_datetime(end_date, is_end=True)

    print(f'開始日期: {start_date}, 結束日期: {end_date}')


    radar_folders = sorted(os.listdir(RADAR_DATASET_PATH))
    cell_files = get_cell_dataset(radar_folders)

    # 原始數值資料，每一個元素是一個DataFrame，每一個DataFrame是一個cell的數值序列
    dataset = []
    # 差分數值資料，每一個元素是一個DataFrame，每一個DataFrame是一個cell的差分數值序列
    diff_dataset = []
    #LSMT 輸入資料(差分數值資料)
    lstm_input_dataset = []
    # ConvLSTM 輸入資料(差分數值資料)
    convlstm_input_dataset = []

    for cell_file, radar_folder in zip(cell_files, radar_folders):
        cell_file_path = os.path.join(CELL_DATASET_PATH, cell_file)
        radar_folder_path = os.path.join(RADAR_DATASET_PATH, radar_folder)

        date_part, time_part = cell_file.split('_')[0].split('-')  # '20210101', '000000'
        dt = datetime.strptime(date_part + time_part, '%Y%m%d%H%M%S')
        target_date = dt.strftime('%Y%m%d%H%M%S')

        if not (start_date <= target_date <= end_date):
            continue

        # ============= 處理單一個數值序列資料 =============
        # 讀取CSV數據並計算差值
        cell_data = pd.read_csv(cell_file_path, encoding='utf-8',
                                dtype={'fileName': str, 'day': str, 'time': str})

        # print(len(cell_data), cell_file_path)
        if len(cell_data) < (WINDOW_SIZE + STEP_SIZE) + 1:
            # 資料不夠長，無法進行滑動窗口處理(至少需要 window_size + step_size + 1 筆資料)
            print(f"資料長度不足，跳過 {cell_file_path}")
            continue

        # 計算經緯度差分
        data_diff = cell_data[[LATITUDE, LONGITUDE]
                              ].diff().dropna().reset_index(drop=True)

        # 提取經度和緯度差值
        lat_diff = cell_data[LATITUDE].diff().dropna().reset_index(drop=True)
        lng_diff = cell_data[LONGITUDE].diff().dropna().reset_index(drop=True)

        # ============= 處理單一個雷達序列資料 =============
        radars = []
        radar_names = sorted(os.listdir(radar_folder_path))
        for radar_name in radar_names:
            radar_path = os.path.join(radar_folder_path, radar_name)
            radar = np.load(radar_path)
            radar_resized = cv2.resize(radar, (HIGHT, WIDTH))
            radars.append(radar_resized)

        # 計算雷達圖片差分
        diff_radars = radar_grid_diff_processing(np.array(radars))

        dataset.append(cell_data)
        diff_dataset.append(data_diff)
        convlstm_input_dataset.append(diff_radars)

    return (dataset, diff_dataset, convlstm_input_dataset)

# %%
# ============= 預測路徑 =============
def predict_path(model: tf.keras.models.Model, dataset_components: tuple) -> np.array:
    dataset, diff_dataset, convlstm_input_dataset = dataset_components

    diff_pred_dict = {}  # 用經緯度差分預測結果
    diff_true_dict = {}  # 用經緯度差分真實結果

    for i, data in enumerate(dataset):

        diff_pred = []  # [(lat_diff, lng_diff), (lat_diff, lng_diff), ...]
        diff_true = []  # [(lat_diff, lng_diff), (lat_diff, lng_diff), ...]

        for j in range(0, len(convlstm_input_dataset[i]) - WINDOW_SIZE - 1, 1):
            # 準備 LSTM 和 ConvLSTM 輸入數據
            convlstm_input = np.expand_dims(
                np.array(convlstm_input_dataset[i][j: j+WINDOW_SIZE], dtype=np.float32), axis=0)
            
            input_data = convlstm_input

            # 預測經緯度差分
            lat_pred, lng_pred = model.predict(input_data)

            # 獲取真實經緯度差分
            lat_d3 = diff_dataset[i][LATITUDE].values[j + WINDOW_SIZE]
            lat_d4 = diff_dataset[i][LATITUDE].values[j + WINDOW_SIZE + 1]
            lng_d3 = diff_dataset[i][LONGITUDE].values[j + WINDOW_SIZE]
            lng_d4 = diff_dataset[i][LONGITUDE].values[j + WINDOW_SIZE + 1]

            true_lat = np.array([lat_d3, lat_d4], dtype=np.float32)
            true_lng = np.array([lng_d3, lng_d4], dtype=np.float32)

            diff_pred.append((np.squeeze(lat_pred), np.squeeze(lng_pred)))
            diff_true.append((true_lat, true_lng))

        diff_pred_dict[i] = diff_pred
        diff_true_dict[i] = diff_true

    print(f'預測資料長度: {len(diff_pred_dict)}, 真實資料長度: {len(diff_true_dict)}')
    return dataset, diff_pred_dict, diff_true_dict

# %%
import math
from haversine import haversine

# ============= 計算誤差(公里) =============
def calculate_mae_distance(lat_mae: float, lon_mae: float, latitude: float = 25.071182):
    lat_km = lat_mae * 111
    lon_km = lon_mae * 111 * math.cos(math.radians(latitude))
    return math.sqrt(lat_km**2 + lon_km**2)

# ============= 評估主函式（輸入2預測2，累積差分 y） =============
def evaluate(dataset: list, pred_dict: dict) -> None:
    # ===== 還原位置誤差（預測累積差加回基準位置） =====
    lat_errors = []
    lng_errors = []
    distances = []

    # 分開統計 t+1 / t+2 的誤差
    lat_errors_1, lng_errors_1, dist_1 = [], [], []
    lat_errors_2, lng_errors_2, dist_2 = [], [], []

    for i, data in enumerate(dataset):
        latitudes = np.array(data[LATITUDE])
        longitudes = np.array(data[LONGITUDE])

        for j, diff_pred in enumerate(pred_dict[i]):
            base_lat = latitudes[j + WINDOW_SIZE]
            base_lng = longitudes[j + WINDOW_SIZE]

            pred_lat1 = base_lat + diff_pred[0][0]
            pred_lat2 = pred_lat1 + diff_pred[0][1]
            pred_lng1 = base_lng + diff_pred[1][0]
            pred_lng2 = pred_lng1 + diff_pred[1][1]

            real_lat1 = latitudes[j + WINDOW_SIZE + 1]
            real_lat2 = latitudes[j + WINDOW_SIZE + 2]
            real_lng1 = longitudes[j + WINDOW_SIZE + 1]
            real_lng2 = longitudes[j + WINDOW_SIZE + 2]

            # 全體誤差
            lat_errors.extend([real_lat1 - pred_lat1, real_lat2 - pred_lat2])
            lng_errors.extend([real_lng1 - pred_lng1, real_lng2 - pred_lng2])
            distances.extend([
                haversine((real_lat1, real_lng1), (pred_lat1, pred_lng1)),
                haversine((real_lat2, real_lng2), (pred_lat2, pred_lng2))
            ])

            # t+1
            lat_errors_1.append(real_lat1 - pred_lat1)
            lng_errors_1.append(real_lng1 - pred_lng1)
            dist_1.append(haversine((real_lat1, real_lng1), (pred_lat1, pred_lng1)))

            # t+2
            lat_errors_2.append(real_lat2 - pred_lat2)
            lng_errors_2.append(real_lng2 - pred_lng2)
            dist_2.append(haversine((real_lat2, real_lng2), (pred_lat2, pred_lng2)))

    # ========= 全部預測誤差 =========
    lat_mae_pos = np.mean(np.abs(lat_errors))
    lng_mae_pos = np.mean(np.abs(lng_errors))
    lat_mse_pos = np.mean(np.square(lat_errors))
    lng_mse_pos = np.mean(np.square(lng_errors))
    lat_rmse_pos = np.sqrt(lat_mse_pos)
    lng_rmse_pos = np.sqrt(lng_mse_pos)
    avg_distance = np.mean(distances)

    print("=== 經緯度位置（還原後）總體評估 ===")
    print(f'Latitude MSE: {lat_mse_pos:.6f} 度')
    print(f'Longitude MSE: {lng_mse_pos:.6f} 度')
    print(f'Latitude MAE: {lat_mae_pos:.6f} 度')
    print(f'Longitude MAE: {lng_mae_pos:.6f} 度')
    print(f'Latitude RMSE: {lat_rmse_pos:.6f}')
    print(f'Longitude RMSE: {lng_rmse_pos:.6f}')
    print(f'Average Haversine distance error: {avg_distance:.3f} km\n')

    # ========= t+1 預測誤差 =========
    lat1_mae = np.mean(np.abs(lat_errors_1))
    lng1_mae = np.mean(np.abs(lng_errors_1))
    lat1_mse = np.mean(np.square(lat_errors_1))
    lng1_mse = np.mean(np.square(lng_errors_1))
    lat1_rmse = np.sqrt(np.mean(np.square(lat_errors_1)))
    lng1_rmse = np.sqrt(np.mean(np.square(lng_errors_1)))
    dist1_avg = np.mean(dist_1)

    print("=== 第一步預測 (t+1) 評估 ===")
    print(f'Latitude MSE: {lat1_mse:.6f} 度')
    print(f'Longitude MSE: {lng1_mse:.6f} 度')
    print(f'Latitude MAE: {lat1_mae:.6f} 度')
    print(f'Longitude MAE: {lng1_mae:.6f} 度')
    print(f'Latitude RMSE: {lat1_rmse:.6f}')
    print(f'Longitude RMSE: {lng1_rmse:.6f}')
    print(f'Average Haversine distance error: {dist1_avg:.3f} km\n')

    # ========= t+2 預測誤差 =========
    lat2_mae = np.mean(np.abs(lat_errors_2))
    lng2_mae = np.mean(np.abs(lng_errors_2))
    lat2_mse = np.mean(np.square(lat_errors_2))
    lng2_mse = np.mean(np.square(lng_errors_2))
    lat2_rmse = np.sqrt(np.mean(np.square(lat_errors_2)))
    lng2_rmse = np.sqrt(np.mean(np.square(lng_errors_2)))
    dist2_avg = np.mean(dist_2)

    print("=== 第二步預測 (t+2) 評估 ===")
    print(f'Latitude MSE: {lat2_mse:.6f} 度')
    print(f'Longitude MSE: {lng2_mse:.6f} 度')
    print(f'Latitude MAE: {lat2_mae:.6f} 度')
    print(f'Longitude MAE: {lng2_mae:.6f} 度')
    print(f'Latitude RMSE: {lat2_rmse:.6f}')
    print(f'Longitude RMSE: {lng2_rmse:.6f}')
    print(f'Average Haversine distance error: {dist2_avg:.3f} km')

# %%
# ============= 繪製路徑 =============
def plot_path(dataset: list, diff_pred_dict: dict) -> None:
    fig = plt.figure(figsize=(10, 6))
    ax = plt.axes(projection=ccrs.PlateCarree())  # 經緯度座標系

    # =================== 統計所有經緯度的最大最小值 ===================
    all_lats = []
    all_lngs = []

    for i, data in enumerate(dataset):
        lats = np.array(data[LATITUDE])
        lngs = np.array(data[LONGITUDE])
        all_lats.extend(lats)
        all_lngs.extend(lngs)

    min_lat, max_lat = min(all_lats), max(all_lats)
    min_lng, max_lng = min(all_lngs), max(all_lngs)

    # =================== 繪圖開始 ===================
    ax.coastlines(resolution='10m', linewidth=1)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5)
    ax.add_feature(cfeature.LAND, facecolor='lightgray')

    # 設定經緯度邊界，加 buffer
    lat_buffer = (max_lat - min_lat) * 0.05
    lng_buffer = (max_lng - min_lng) * 0.05
    # ax.set_extent([min_lng - lng_buffer, max_lng + lng_buffer,
    #                min_lat - lat_buffer, max_lat + lat_buffer], crs=ccrs.PlateCarree())

    # '梅雨鋒面個案_2021-05-30'
    # ax.set_extent([119.8001659, 123.8208661, 23.81446730319214, 26.75911663296509], crs=ccrs.PlateCarree())
    # min_lat, max_lat = 23.45, 26.5
    # min_lng, max_lng = 119.8, 123.8

    # '午後對流個案_2022-08-25'
    # min_lat, max_lat = 23.25, 25.75
    # min_lng, max_lng = 119.75, 122.5
    # extent = [min_lng, max_lng, min_lat, max_lat]  # 台灣範圍
    # print(f'設定經緯度範圍: {extent}')
    # ax.set_extent(extent, crs=ccrs.PlateCarree())

    # '烟花颱風個案_2021-07-22'
    min_lat, max_lat = 22.75, 27.45
    min_lng, max_lng = 120.15, 124.15
    extent = [min_lng, max_lng, min_lat, max_lat]  # 台灣範圍
    print(f'設定經緯度範圍: {extent}')
    ax.set_extent(extent, crs=ccrs.PlateCarree())


    # 設定 X、Y 軸刻度（每隔 0.5 度一格可調整）
    x_ticks = np.round(np.arange(min_lng, max_lng + 0.1, 0.5), 2)
    y_ticks = np.round(np.arange(min_lat, max_lat + 0.1, 0.5), 2)
    ax.set_xticks(x_ticks, crs=ccrs.PlateCarree())
    ax.set_yticks(y_ticks, crs=ccrs.PlateCarree())
    ax.tick_params(labelsize=8)
    
    # 可選：顯示經緯度刻度線
    ax.gridlines(draw_labels=False, linewidth=0.5,
                 color='gray', alpha=0.5, linestyle='--')

    # =================== 畫實際與預測軌跡 ===================
    for i, data in enumerate(dataset):
        latitudes = np.array(data[LATITUDE])
        longitudes = np.array(data[LONGITUDE])

        # 預測位置還原（兩步）
        pred_lat1_list = []
        pred_lng1_list = []
        pred_lat2_list = []
        pred_lng2_list = []

        for j, diff_pred in enumerate(diff_pred_dict[i]):
            base_lat = latitudes[j + WINDOW_SIZE]
            base_lng = longitudes[j + WINDOW_SIZE]

            # diff_pred: [[lat_t+1, lat_t+2], [lng_t+1, lng_t+2]]
            pred_lat1 = base_lat + diff_pred[0][0]
            pred_lat2 = pred_lat1 + diff_pred[0][1]
            pred_lng1 = base_lng + diff_pred[1][0]
            pred_lng2 = pred_lng1 + diff_pred[1][1]

            pred_lat1_list.append(pred_lat1)
            pred_lat2_list.append(pred_lat2)
            pred_lng1_list.append(pred_lng1)
            pred_lng2_list.append(pred_lng2)

        # 畫實際路徑與預測路徑
        plt.plot(longitudes, latitudes, marker='o',
                 markersize=1.5, color='#1f77b4', linewidth=0.5)  # 實際
        plt.plot(pred_lng1_list, pred_lat1_list, marker='o',
                 markersize=1.5, color='#ff7f0e', linewidth=0.5)  # 預測 t+1
        plt.plot(pred_lng2_list, pred_lat2_list, marker='o',
                 markersize=1.5, color='#2ca02c', linewidth=0.5)  # 預測 t+2

    plt.legend(['真實路徑', '預測路徑'], prop=jheng_hei_font, fontsize=8)
    # plt.title(f'LSTM 預測路徑', fontproperties=jheng_hei_b_font, fontsize=14)
    plt.xlabel('經度', fontproperties=jheng_hei_b_font, fontsize=12)
    plt.ylabel('緯度', fontproperties=jheng_hei_b_font, fontsize=12)
    plt.tight_layout()
    plt.show()

# %%
# 測試集資料範圍: 2022-07-01 ~ 2022-08-31 可按照需求調整
# start_date = '2022-10-04'
# end_date = '2022-10-04'
# start_date = '2022-11-27'
# end_date = '2022-11-29'

# start_date = '2022-05-30'
# end_date = '2022-05-30' 

# 2021-05-30 04 ~ 10 UTC 梅雨鋒面
# start_date = '2021-05-30'
# end_date = '2021-05-30' 

# ===================================
# 2021-01-16  冬季降雨個案(不太好看)
# start_date = '2021-01-16 06:00:00'
# end_date = '2021-01-16 12:00:00'
# 2021-05-30  梅雨鋒面個案
# start_date = '2021-05-30 04:00:00'
# end_date = '2021-05-30 10:00:00'
# 2022-08-25  午後對流個案(很短很小)
# start_date = '2022-08-25 05:00:00'
# end_date = '2022-08-25 11:00:00'
# 2021-07-22  烟花颱風個案(先不要)
start_date = '2021-07-22 06:00:00'
end_date = '2021-07-22 12:00:00'
# 2022-09-04  軒嵐諾颱風
# start_date = '2022-09-04 11:00:00'
# end_date = '2022-09-04 17:00:00'
# ===================================

# 讀取模型
model = load_model(model_path=MODEL_PATH, custom_objects={'rmse': rmse})
# 列印模型結構
# print(model.summary())

print('--------------模型讀取成功--------------')

# 讀取資料縮放器
# scaler = load_scaler(scaler_path='config/lat_lon_scaler.gz')

# 讀取資料(原始數值資料，差分數值資料，LSTM輸入數據，ConvLSTM輸入數據)
dataset_components = read_data(
    start_date=start_date,  
    end_date=end_date,  
)

# 預測差分路徑
dataset, diff_pred_dict, diff_true_dict = predict_path(
    model=model, dataset_components=dataset_components)

# 評估模型
evaluate(dataset, diff_pred_dict)

# 繪製預測路徑與真實路徑
plot_path(dataset, diff_pred_dict)
# Out:
# --------------模型讀取成功--------------
# 個案日期 20210530 ~ 20210530
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_15_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_21_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_25_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_39_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_48_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_50_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_5_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_61_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_67_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_74_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-000431_7_000431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-001032_42_001032.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-001032_76_001032.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-001633_55_001633.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-002234_91_002234.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-002835_10_002835.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-002835_12_002835.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-002835_14_002835.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-003437_76_003437.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-003437_92_003437.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-004039_45_004039.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-004039_47_004039.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-004640_63_004640.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-005242_12_005242.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-005844_24_005844.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-010444_32_010444.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-011046_42_011046.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-011046_43_011046.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-011648_58_011648.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-011648_62_011648.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-011648_68_011648.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-011648_75_011648.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-011648_96_011648.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-012851_32_012851.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-013452_5_013452.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-014053_21_014053.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-014653_19_014653.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-014653_40_014653.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-015255_55_015255.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-015855_70_015855.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-015855_72_015855.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-020649_52_020649.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-020649_59_020649.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-020649_81_020649.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-020649_93_020649.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-020649_95_020649.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-021852_20_021852.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-022453_31_022453.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-022453_35_022453.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-022453_37_022453.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-022453_50_022453.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-023054_62_023054.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-023054_77_023054.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-023654_87_023654.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-024255_8_024255.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-024857_22_024857.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-024857_27_024857.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-024857_28_024857.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-024857_40_024857.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-024857_41_024857.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-025459_51_025459.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-025459_56_025459.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-030100_45_030100.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-030100_55_030100.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-030100_74_030100.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-030701_7_030701.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-030701_91_030701.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-030701_94_030701.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-031302_15_031302.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-031302_25_031302.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-031904_42_031904.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-031904_57_031904.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-032505_13_032505.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-032505_61_032505.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-032505_69_032505.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-033107_85_033107.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-033107_98_033107.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-033708_21_033708.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-033708_44_033708.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-034309_30_034309.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-034309_37_034309.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-034309_46_034309.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-034309_48_034309.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-034309_52_034309.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-034910_100_034910.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-034910_67_034910.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-034910_95_034910.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-034910_97_034910.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-035512_10_035512.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-035512_13_035512.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040113_45_040113.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040113_54_040113.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040113_60_040113.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040113_63_040113.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040113_70_040113.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040714_29_040714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040714_79_040714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040714_80_040714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040714_83_040714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040714_8_040714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-040714_92_040714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-042516_47_042516.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-042516_56_042516.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_11_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_14_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_27_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_34_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_43_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_49_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_4_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_57_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_61_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_67_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_72_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_73_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_76_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_85_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_90_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_97_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-043718_9_043718.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-044319_3_044319.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-044319_46_044319.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-044319_58_044319.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-044319_60_044319.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-044319_70_044319.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-044920_69_044920.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-044920_87_044920.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-044920_88_044920.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-045521_19_045521.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-045521_22_045521.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-045521_51_045521.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-045521_93_045521.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-050121_15_050121.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-050121_27_050121.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-050121_49_050121.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-050121_97_050121.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-050722_35_050722.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-050722_41_050722.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-050722_70_050722.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-050722_77_050722.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-051323_100_051323.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-051323_2_051323.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-051323_4_051323.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-051323_74_051323.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-051924_38_051924.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-051924_44_051924.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-052526_3_052526.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053128_16_053128.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053128_19_053128.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053128_20_053128.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053128_37_053128.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053128_41_053128.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053128_46_053128.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053128_48_053128.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053128_63_053128.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053729_36_053729.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053729_71_053729.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-053729_82_053729.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-054331_17_054331.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-054331_44_054331.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-054933_38_054933.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-054933_4_054933.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-055534_51_055534.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-055534_55_055534.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-060736_15_060736.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061337_18_061337.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061337_19_061337.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061337_20_061337.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061337_23_061337.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061337_30_061337.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061337_32_061337.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061938_14_061938.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061938_27_061938.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061938_40_061938.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061938_41_061938.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-061938_48_061938.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-062539_10_062539.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-062539_36_062539.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-062539_66_062539.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-062539_67_062539.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-062539_69_062539.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-063140_77_063140.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-063741_25_063741.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-063741_3_063741.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064343_11_064343.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064343_13_064343.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064343_19_064343.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064343_21_064343.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064343_22_064343.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064343_8_064343.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064343_9_064343.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064944_33_064944.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064944_35_064944.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-064944_6_064944.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-065544_40_065544.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-065544_61_065544.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-070145_20_070145.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-070145_23_070145.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-070145_24_070145.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-070145_2_070145.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-070145_4_070145.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-070746_30_070746.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-070746_36_070746.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-070746_74_070746.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-071347_35_071347.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-071347_94_071347.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-071948_13_071948.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-071948_14_071948.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-071948_17_071948.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-071948_18_071948.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-072550_40_072550.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-072550_46_072550.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-073151_71_073151.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-073151_86_073151.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-073751_15_073751.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-073751_2_073751.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-073751_57_073751.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-073751_89_073751.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-074352_49_074352.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-074352_54_074352.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-074352_61_074352.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-074352_65_074352.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-074352_68_074352.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-074954_100_074954.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-075555_43_075555.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-075555_8_075555.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080157_14_080157.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080157_44_080157.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080157_59_080157.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080157_60_080157.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080157_78_080157.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080157_79_080157.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080758_11_080758.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080758_12_080758.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080758_39_080758.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-080758_42_080758.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-081400_55_081400.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-081400_68_081400.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-081400_82_081400.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-081400_84_081400.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-081400_93_081400.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-081400_98_081400.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-082000_21_082000.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-082000_52_082000.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-082602_30_082602.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-082602_34_082602.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-082602_47_082602.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-083203_49_083203.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-083203_60_083203.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-083203_61_083203.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-083804_17_083804.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-083804_33_083804.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-083804_35_083804.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-083804_42_083804.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-084405_14_084405.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-084405_41_084405.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-084405_67_084405.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-084405_74_084405.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-084405_78_084405.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-084405_87_084405.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-084405_90_084405.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-084405_91_084405.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-084405_94_084405.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-085007_16_085007.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-085608_13_085608.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-085608_29_085608.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-085608_43_085608.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-090209_49_090209.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-090209_82_090209.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-090809_14_090809.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-090809_30_090809.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-090809_6_090809.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-090809_88_090809.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-090809_95_090809.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-091410_11_091410.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-091410_12_091410.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-091410_17_091410.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-091410_24_091410.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-092012_20_092012.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-092012_45_092012.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-092012_46_092012.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-092012_65_092012.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-092611_86_092611.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-093212_32_093212.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-093212_51_093212.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-093212_79_093212.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-093814_26_093814.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-093814_40_093814.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-093814_80_093814.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-093814_81_093814.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-094415_94_094415.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-095015_57_095015.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-095617_93_095617.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_13_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_14_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_18_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_33_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_34_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_38_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_3_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_41_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_43_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_44_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_45_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_4_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_54_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_63_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_65_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_74_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101016_79_101016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101618_21_101618.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101618_29_101618.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101618_42_101618.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101618_55_101618.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101618_56_101618.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101618_84_101618.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-101618_91_101618.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-102218_15_102218.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-102218_19_102218.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-102218_30_102218.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-102218_9_102218.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-102819_6_102819.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-102819_83_102819.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-103421_20_103421.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-104022_46_104022.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-104022_47_104022.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-104022_68_104022.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-104022_69_104022.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-104022_71_104022.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-104624_2_104624.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-104624_4_104624.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-104624_88_104624.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-104624_95_104624.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-105225_24_105225.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-105225_41_105225.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-105225_63_105225.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-105826_65_105826.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-105826_73_105826.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-105826_81_105826.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-105826_97_105826.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-105826_99_105826.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-110427_46_110427.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-110427_77_110427.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-111028_49_111028.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-111629_26_111629.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-111629_43_111629.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-111629_62_111629.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-111629_67_111629.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-111629_72_111629.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-112229_29_112229.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-112229_34_112229.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-112229_36_112229.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-112229_4_112229.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-112229_82_112229.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-112829_12_112829.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-112829_50_112829.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-112829_6_112829.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-113431_25_113431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-113431_90_113431.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-114033_45_114033.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-114033_60_114033.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-114033_93_114033.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-114634_23_114634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-114634_31_114634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-114634_44_114634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-114634_54_114634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-114634_67_114634.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115236_51_115236.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115236_64_115236.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115236_65_115236.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115236_92_115236.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115837_12_115837.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115837_29_115837.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115837_35_115837.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115837_39_115837.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115837_40_115837.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-115837_57_115837.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-120439_13_120439.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-120439_49_120439.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-120439_83_120439.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121038_42_121038.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121038_45_121038.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121038_47_121038.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121038_52_121038.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121038_66_121038.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121038_80_121038.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121038_93_121038.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121038_94_121038.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121639_100_121639.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-121639_6_121639.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-122240_51_122240.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-122842_13_122842.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-122842_18_122842.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-122842_90_122842.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-123442_31_123442.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-123442_33_123442.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-123442_50_123442.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-124043_68_124043.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-124043_86_124043.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-124043_88_124043.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-124043_94_124043.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-124644_46_124644.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-124644_63_124644.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-124644_6_124644.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-124644_81_124644.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-125245_100_125245.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-125245_78_125245.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-125245_89_125245.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-125245_91_125245.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-125846_29_125846.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-125846_82_125846.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-130447_43_130447.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-130447_49_130447.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-130447_5_130447.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-130447_84_130447.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-131048_28_131048.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-131048_9_131048.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-131649_18_131649.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-131649_53_131649.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-131649_64_131649.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-132250_6_132250.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-132250_96_132250.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-132250_98_132250.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-132852_12_132852.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-132852_19_132852.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-132852_37_132852.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-132852_68_132852.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-133453_50_133453.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-133453_55_133453.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-133453_60_133453.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-133453_67_133453.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-134053_76_134053.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-134053_79_134053.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-134653_92_134653.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-135254_2_135254.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-135855_10_135855.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-135855_13_135855.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-135855_15_135855.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-135855_75_135855.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-141659_48_141659.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-142902_13_142902.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-142902_14_142902.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-142902_69_142902.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-142902_88_142902.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-143503_74_143503.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-144105_100_144105.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-144706_15_144706.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-144706_17_144706.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-145307_20_145307.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-145307_21_145307.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-152915_41_152915.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-155321_54_155321.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-161727_63_161727.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-163530_59_163530.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-163530_68_163530.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-174742_1_174742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-205017_1_205017.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210530-214423_1_214423.csv
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 1s 1s/step
# ...
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 預測資料長度: 190, 真實資料長度: 190
# === 經緯度位置（還原後）總體評估 ===
# Latitude MSE: 0.001003 度
# Longitude MSE: 0.000863 度
# Latitude MAE: 0.026093 度
# Longitude MAE: 0.024034 度
# Latitude RMSE: 0.031663
# Longitude RMSE: 0.029383
# Average Haversine distance error: 4.075 km
#
# === 第一步預測 (t+1) 評估 ===
# Latitude MSE: 0.000554 度
# Longitude MSE: 0.000360 度
# Latitude MAE: 0.020154 度
# Longitude MAE: 0.016085 度
# Latitude RMSE: 0.023537
# Longitude RMSE: 0.018987
# Average Haversine distance error: 2.957 km
#
# === 第二步預測 (t+2) 評估 ===
# Latitude MSE: 0.001451 度
# Longitude MSE: 0.001366 度
# Latitude MAE: 0.032032 度
# Longitude MAE: 0.031983 度
# Latitude RMSE: 0.038093
# Longitude RMSE: 0.036963
# Average Haversine distance error: 5.192 km
