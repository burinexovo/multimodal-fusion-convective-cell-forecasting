# %%
import os  # 用於文件操作
import cv2  # 用於影像處理
import math  # 用於數學運算
import numpy as np  # 用於數值運算
import pandas as pd  # 用於數據處理
import joblib  # 用於保存和加載資料縮放器
import matplotlib.pyplot as plt  # 用於繪圖
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from datetime import datetime  # 用於時間操作
from sklearn.preprocessing import MinMaxScaler  # 用於資料縮放

import tensorflow as tf  # 用於構建模型
from tensorflow.keras import backend as K  # 用於自定義損失函數

# %%
SPLIT_DATA_MODE = 'month'  # 數據分割模式 sequence or month
LATITUDE = 'Latitude'
LONGITUDE = 'Longitude'
WINDOW_SIZE = 4
STEP_SIZE = 2
# CELL_DATASET_PATH = r'E:\YuCheng\cell_data_processed\cells'
CELL_DATASET_PATH = r'H:\cell_data_processed\cells'
SCALER_PATH = rf'config\{SPLIT_DATA_MODE}\lstm_multitask_scaler.gz'
MODEL_PATH = rf'weights\{SPLIT_DATA_MODE}\non_cumulative_diff\lstm_multitask\lstm_mt_diff4-2_e16v0.0004'
# weights\month\non_cumulative_diff\lstm_multitask\lstm_mt_diff2-2_e04v0.0007

# %%
# ============= 均方根誤差 =============
def rmse(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# ============= 計算差分資料 =============
def data_diff_processing(data):
    data_filtered = data[['Latitude', 'Longitude']]
    data_diff = data_filtered.diff().dropna().reset_index(drop=True)
    return data_diff

# ============= 讀取模型 =============
def load_model(model_path: str, custom_objects: dict = None) -> tf.keras.models.Model:
    if custom_objects is None:
        return tf.keras.models.load_model(model_path)
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# ============= 讀取scaler =============
def load_scaler(scaler_path: str) -> joblib.load:
    return joblib.load(scaler_path)

# ============= 讀取資料 =============
def read_data(start_date: str, end_date: str, scaler: MinMaxScaler) -> tuple:
    start_date = datetime.strptime(start_date, '%Y-%m-%d').strftime('%Y%m%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d').strftime('%Y%m%d')
    print(f'個案日期 {start_date} ~ {end_date}')

    cell_files = sorted(os.listdir(CELL_DATASET_PATH))

    # 原始數值資料，每一個元素是一個DataFrame，每一個DataFrame是一個cell的數值序列
    dataset = []
    # 差分數值資料，每一個元素是一個DataFrame，每一個DataFrame是一個cell的差分數值序列
    diff_dataset = []
    # LSTM 輸入資料(差分數值資料)
    lstm_input_dataset = []

    for cell_file in cell_files:
        cell_file_path = os.path.join(CELL_DATASET_PATH, cell_file)

        target_date = datetime.strptime(
            cell_file.split('-')[0], '%Y%m%d').strftime('%Y%m%d')

        if not (start_date <= target_date <= end_date):
            continue

        # ============= 處理單一個數值序列資料 =============
        # 讀取CSV數據並計算差值
        cell_data = pd.read_csv(cell_file_path, encoding='utf-8',
                                dtype={'fileName': str, 'day': str, 'time': str})
        
        # print(len(cell_data), cell_file_path)
        if len(cell_data) < (5 + STEP_SIZE) + 1:
            # 資料不夠長，無法進行滑動窗口處理(至少需要 window_size + step_size + 1 筆資料)
            print(f"資料長度不足，跳過 {cell_file_path}")
            continue

        # 計算經緯度差分
        data_diff = cell_data[[LATITUDE, LONGITUDE]
                              ].diff().dropna().reset_index(drop=True)

        # 提取經度和緯度差值
        lat_diff = cell_data[LATITUDE].diff().dropna().reset_index(drop=True)
        lng_diff = cell_data[LONGITUDE].diff().dropna().reset_index(drop=True)

        combined_data = np.vstack([lat_diff.values, lng_diff.values]).T  # 經緯度差異合併

        # 使用scaler對資料進行縮放
        scaled_data_diff = scaler.transform(combined_data)

        dataset.append(cell_data)
        diff_dataset.append(data_diff)
        lstm_input_dataset.append(scaled_data_diff)

    return (dataset, diff_dataset, lstm_input_dataset)

# %%
# ============= 預測路徑 =============
def predict_path(model: tf.keras.models.Model, dataset_components: tuple) -> np.array:
    dataset, diff_dataset, lstm_input_dataset = dataset_components

    diff_pred_dict = {}  # 用經緯度差分預測結果
    diff_true_dict = {}  # 用經緯度差分真實結果

    for i, data in enumerate(dataset):

        diff_pred = []  # [(lat_diff, lng_diff), (lat_diff, lng_diff), ...]
        diff_true = []  # [(lat_diff, lng_diff), (lat_diff, lng_diff), ...]

        for j in range(0, len(lstm_input_dataset[i]) - WINDOW_SIZE - 1, 1):
            # 準備 LSTM 和 ConvLSTM 輸入數據
            lstm_input = np.expand_dims(
                np.array(lstm_input_dataset[i][j: j+WINDOW_SIZE], dtype=np.float32), axis=0)
            
            input_data = lstm_input

            # 預測經緯度差分
            lat_pred, lng_pred = model.predict(input_data)

            # 獲取真實經緯度差分
            lat_d3 = diff_dataset[i][LATITUDE].values[j + WINDOW_SIZE]
            lat_d4 = diff_dataset[i][LATITUDE].values[j + WINDOW_SIZE + 1]
            lng_d3 = diff_dataset[i][LONGITUDE].values[j + WINDOW_SIZE]
            lng_d4 = diff_dataset[i][LONGITUDE].values[j + WINDOW_SIZE + 1]

            true_lat = np.array([lat_d3, lat_d4], dtype=np.float32)
            true_lng = np.array([lng_d3, lng_d4], dtype=np.float32)

            diff_pred.append((np.squeeze(lat_pred), np.squeeze(lng_pred)))
            diff_true.append((true_lat, true_lng))

        diff_pred_dict[i] = diff_pred
        diff_true_dict[i] = diff_true

    print(f'預測資料長度: {len(diff_pred_dict)}, 真實資料長度: {len(diff_true_dict)}')
    return dataset, diff_pred_dict, diff_true_dict

# %%
import math
from haversine import haversine

# ============= 計算誤差(公里) =============
def calculate_mae_distance(lat_mae: float, lon_mae: float, latitude: float = 25.071182):
    lat_km = lat_mae * 111
    lon_km = lon_mae * 111 * math.cos(math.radians(latitude))
    return math.sqrt(lat_km**2 + lon_km**2)

# ============= 評估主函式（輸入2預測2，累積差分 y） =============
def evaluate(dataset: list, pred_dict: dict) -> None:
    # ===== 還原位置誤差（預測累積差加回基準位置） =====
    lat_errors = []
    lng_errors = []
    distances = []

    # 分開統計 t+1 / t+2 的誤差
    lat_errors_1, lng_errors_1, dist_1 = [], [], []
    lat_errors_2, lng_errors_2, dist_2 = [], [], []

    for i, data in enumerate(dataset):
        latitudes = np.array(data[LATITUDE])
        longitudes = np.array(data[LONGITUDE])

        for j, diff_pred in enumerate(pred_dict[i]):
            base_lat = latitudes[j + WINDOW_SIZE]
            base_lng = longitudes[j + WINDOW_SIZE]

            pred_lat1 = base_lat + diff_pred[0][0]
            pred_lat2 = pred_lat1 + diff_pred[0][1]
            pred_lng1 = base_lng + diff_pred[1][0]
            pred_lng2 = pred_lng1 + diff_pred[1][1]

            real_lat1 = latitudes[j + WINDOW_SIZE + 1]
            real_lat2 = latitudes[j + WINDOW_SIZE + 2]
            real_lng1 = longitudes[j + WINDOW_SIZE + 1]
            real_lng2 = longitudes[j + WINDOW_SIZE + 2]

            # 全體誤差
            lat_errors.extend([real_lat1 - pred_lat1, real_lat2 - pred_lat2])
            lng_errors.extend([real_lng1 - pred_lng1, real_lng2 - pred_lng2])
            distances.extend([
                haversine((real_lat1, real_lng1), (pred_lat1, pred_lng1)),
                haversine((real_lat2, real_lng2), (pred_lat2, pred_lng2))
            ])

            # t+1
            lat_errors_1.append(real_lat1 - pred_lat1)
            lng_errors_1.append(real_lng1 - pred_lng1)
            dist_1.append(haversine((real_lat1, real_lng1), (pred_lat1, pred_lng1)))

            # t+2
            lat_errors_2.append(real_lat2 - pred_lat2)
            lng_errors_2.append(real_lng2 - pred_lng2)
            dist_2.append(haversine((real_lat2, real_lng2), (pred_lat2, pred_lng2)))

    # ========= 全部預測誤差 =========
    lat_mae_pos = np.mean(np.abs(lat_errors))
    lng_mae_pos = np.mean(np.abs(lng_errors))
    lat_mse_pos = np.mean(np.square(lat_errors))
    lng_mse_pos = np.mean(np.square(lng_errors))
    lat_rmse_pos = np.sqrt(lat_mse_pos)
    lng_rmse_pos = np.sqrt(lng_mse_pos)
    avg_distance = np.mean(distances)

    print("=== 經緯度位置（還原後）總體評估 ===")
    print(f'Latitude MSE: {lat_mse_pos:.6f} 度')
    print(f'Longitude MSE: {lng_mse_pos:.6f} 度')
    print(f'Latitude MAE: {lat_mae_pos:.6f} 度')
    print(f'Longitude MAE: {lng_mae_pos:.6f} 度')
    print(f'Latitude RMSE: {lat_rmse_pos:.6f}')
    print(f'Longitude RMSE: {lng_rmse_pos:.6f}')
    print(f'Average Haversine distance error: {avg_distance:.3f} km\n')

    # ========= t+1 預測誤差 =========
    lat1_mae = np.mean(np.abs(lat_errors_1))
    lng1_mae = np.mean(np.abs(lng_errors_1))
    lat1_mse = np.mean(np.square(lat_errors_1))
    lng1_mse = np.mean(np.square(lng_errors_1))
    lat1_rmse = np.sqrt(np.mean(np.square(lat_errors_1)))
    lng1_rmse = np.sqrt(np.mean(np.square(lng_errors_1)))
    dist1_avg = np.mean(dist_1)

    print("=== 第一步預測 (t+1) 評估 ===")
    print(f'Latitude MSE: {lat1_mse:.6f} 度')
    print(f'Longitude MSE: {lng1_mse:.6f} 度')
    print(f'Latitude MAE: {lat1_mae:.6f} 度')
    print(f'Longitude MAE: {lng1_mae:.6f} 度')
    print(f'Latitude RMSE: {lat1_rmse:.6f}')
    print(f'Longitude RMSE: {lng1_rmse:.6f}')
    print(f'Average Haversine distance error: {dist1_avg:.3f} km\n')

    # ========= t+2 預測誤差 =========
    lat2_mae = np.mean(np.abs(lat_errors_2))
    lng2_mae = np.mean(np.abs(lng_errors_2))
    lat2_mse = np.mean(np.square(lat_errors_2))
    lng2_mse = np.mean(np.square(lng_errors_2))
    lat2_rmse = np.sqrt(np.mean(np.square(lat_errors_2)))
    lng2_rmse = np.sqrt(np.mean(np.square(lng_errors_2)))
    dist2_avg = np.mean(dist_2)

    print("=== 第二步預測 (t+2) 評估 ===")
    print(f'Latitude MSE: {lat2_mse:.6f} 度')
    print(f'Longitude MSE: {lng2_mse:.6f} 度')
    print(f'Latitude MAE: {lat2_mae:.6f} 度')
    print(f'Longitude MAE: {lng2_mae:.6f} 度')
    print(f'Latitude RMSE: {lat2_rmse:.6f}')
    print(f'Longitude RMSE: {lng2_rmse:.6f}')
    print(f'Average Haversine distance error: {dist2_avg:.3f} km')

# %%
# ============= 繪製路徑 =============
def plot_path(dataset: list, diff_pred_dict: dict) -> None:
    fig = plt.figure(figsize=(10, 6))
    ax = plt.axes(projection=ccrs.PlateCarree())  # 經緯度座標系

    # =================== 統計所有經緯度的最大最小值 ===================
    all_lats = []
    all_lngs = []

    for i, data in enumerate(dataset):
        lats = np.array(data[LATITUDE])
        lngs = np.array(data[LONGITUDE])
        all_lats.extend(lats)
        all_lngs.extend(lngs)

    min_lat, max_lat = min(all_lats), max(all_lats)
    min_lng, max_lng = min(all_lngs), max(all_lngs)

    # =================== 繪圖開始 ===================
    ax.coastlines(resolution='10m', linewidth=1)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5)
    ax.add_feature(cfeature.LAND, facecolor='lightgray')

    # 設定經緯度邊界（可根據實際資料調整）
    lat_buffer = (max_lat - min_lat) * 0.05
    lng_buffer = (max_lng - min_lng) * 0.05
    ax.set_extent([
        min_lng - lng_buffer, max_lng + lng_buffer,
        min_lat - lat_buffer, max_lat + lat_buffer
    ], crs=ccrs.PlateCarree())
    ax.set_extent([120.2320782, 124.1435858, 22.6607914, 26])

    # =================== 畫實際與預測軌跡 ===================
    for i, data in enumerate(dataset):
        latitudes = np.array(data[LATITUDE])
        longitudes = np.array(data[LONGITUDE])

        # 預測位置還原（兩步）
        pred_lat1_list = []
        pred_lng1_list = []
        pred_lat2_list = []
        pred_lng2_list = []

        for j, diff_pred in enumerate(diff_pred_dict[i]):
            base_lat = latitudes[j + WINDOW_SIZE]
            base_lng = longitudes[j + WINDOW_SIZE]

            # diff_pred: [[lat_t+1, lat_t+2], [lng_t+1, lng_t+2]]
            pred_lat1 = base_lat + diff_pred[0][0]
            pred_lat2 = pred_lat1 + diff_pred[0][1]
            pred_lng1 = base_lng + diff_pred[1][0]
            pred_lng2 = pred_lng1 + diff_pred[1][1]

            pred_lat1_list.append(pred_lat1)
            pred_lat2_list.append(pred_lat2)
            pred_lng1_list.append(pred_lng1)
            pred_lng2_list.append(pred_lng2)

        # 畫實際路徑與預測路徑
        plt.plot(longitudes, latitudes, marker='o',
                 markersize=1.5, color='#1f77b4', linewidth=0.5)  # 實際
        plt.plot(pred_lng1_list, pred_lat1_list, marker='o',
                 markersize=1.5, color='#ff7f0e', linewidth=0.5)  # 預測 t+1
        plt.plot(pred_lng2_list, pred_lat2_list, marker='o',
                 markersize=1.5, color='#2ca02c', linewidth=0.5)  # 預測 t+2

    plt.legend(['Ground Truth', 'Prediction t+1', 'Prediction t+2'])
    plt.title(f'LSTM Multitask Prediction ({SPLIT_DATA_MODE})')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.tight_layout()
    # plt.savefig('result/prediction_result.png')
    plt.show()

# %%
# 測試集資料範圍: 2022-07-01 ~ 2022-08-31 可按照需求調整
# start_date = '2022-10-04'
# end_date = '2022-10-04'
# start_date = '2022-12-06'
# end_date = '2022-12-06'
# 時序切割、月份切割共同資料集範圍
# start_date = '2022-11-27'
# end_date = '2022-11-29'

# 2021-05-30 04 ~ 10 UTC 梅雨鋒面
# start_date = '2022-05-30'
# end_date = '2022-05-30' 

# ===================================
# # 2021-01-16  冬季降雨個案(不太好看)
# start_date = '2021-01-16'
# end_date = '2021-01-16'
# 2021-05-30  梅雨鋒面個案
# start_date = '2021-05-30'
# end_date = '2021-05-30'
# # 2022-08-25  午後對流個案(很短很小)
# start_date = '2022-08-25'
# end_date = '2022-08-25'
# # 2021-07-22  烟花颱風個案(先不要)
start_date = '2021-07-22'
end_date = '2021-07-22'
# # 2022-09-04  軒嵐諾颱風
# start_date = '2022-09-04'
# end_date = '2022-09-04'
# ===================================

# 讀取模型
model = load_model(model_path=MODEL_PATH, custom_objects={'rmse': rmse})
# 列印模型結構
# print(model.summary())

print('--------------模型讀取成功--------------')

# 讀取資料縮放器
scaler = load_scaler(scaler_path=SCALER_PATH)

# 讀取資料(原始數值資料，差分數值資料，LSTM輸入數據，ConvLSTM輸入數據)
dataset_components = read_data(
    start_date=start_date,  
    end_date=end_date,  
    scaler=scaler
)

# 預測差分路徑
dataset, diff_pred_dict, diff_true_dict = predict_path(
    model=model, dataset_components=dataset_components)

print(diff_pred_dict)
print(diff_true_dict)

# 評估模型
evaluate(dataset, diff_pred_dict)

# 繪製預測路徑與真實路徑
plot_path(dataset, diff_pred_dict)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# --------------模型讀取成功--------------
# 個案日期 20210722 ~ 20210722
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-000410_37_000410.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-000410_64_000410.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-001015_69_001015.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-001015_73_001015.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-001015_74_001015.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-001015_78_001015.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-001015_84_001015.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-001015_94_001015.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-001620_46_001620.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-001620_59_001620.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-002225_16_002225.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-002225_20_002225.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-011542_11_011542.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-011542_16_011542.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-011542_18_011542.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-011542_5_011542.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-011542_8_011542.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-012147_33_012147.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-012754_40_012754.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-012754_45_012754.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-013359_49_013359.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-013359_50_013359.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-013359_55_013359.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-014005_56_014005.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-014005_58_014005.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-014005_64_014005.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-015822_71_015822.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-020428_74_020428.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-021034_76_021034.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-021034_82_021034.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-022246_86_022246.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-022246_89_022246.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-025315_10_025315.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-025315_34_025315.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-030527_11_030527.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-030527_15_030527.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-032951_35_032951.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-032951_37_032951.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-033556_29_033556.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-033556_41_033556.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-033556_44_033556.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-034808_47_034808.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-040019_61_040019.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-041232_77_041232.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-041837_87_041837.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-043049_6_043049.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-043655_11_043655.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-043655_13_043655.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-044906_27_044906.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-044906_28_044906.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-045512_33_045512.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-045512_35_045512.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-045512_37_045512.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-050723_50_050723.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-051935_61_051935.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-052541_68_052541.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-053146_76_053146.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-053752_33_053752.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-053752_62_053752.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-054357_97_054357.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-054357_98_054357.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-055003_5_055003.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-055003_92_055003.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-055608_10_055608.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-060820_26_060820.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-060820_27_060820.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-060820_28_060820.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-060820_37_060820.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-061425_40_061425.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-062031_42_062031.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-062637_56_062637.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-064658_3_064658.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-064658_5_064658.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-064658_84_064658.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-065303_13_065303.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-065303_19_065303.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-065303_32_065303.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-065907_35_065907.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-070513_46_070513.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-071119_61_071119.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-071119_78_071119.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-071119_80_071119.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-072331_100_072331.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-072331_11_072331.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-072331_99_072331.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-072937_14_072937.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-072937_18_072937.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-072937_20_072937.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-072937_21_072937.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-073542_30_073542.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-073542_31_073542.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-073542_41_073542.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-074148_28_074148.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-074148_2_074148.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-074148_44_074148.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-074148_51_074148.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-074754_11_074754.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-074754_70_074754.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-074754_81_074754.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-074754_84_074754.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-075400_61_075400.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-080006_16_080006.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-080006_17_080006.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-080006_18_080006.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-080006_48_080006.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-080612_7_080612.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-081217_40_081217.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-081217_42_081217.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-081217_45_081217.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-081823_30_081823.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-082429_12_082429.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-082429_97_082429.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-083034_18_083034.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-083034_47_083034.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-083640_25_083640.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-083640_32_083640.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-083640_86_083640.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-084246_19_084246.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-084246_63_084246.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-085455_6_085455.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-085455_7_085455.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-085455_85_085455.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-085455_90_085455.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-085455_91_085455.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-090102_99_090102.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-090708_13_090708.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-090708_24_090708.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-090708_3_090708.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-091919_41_091919.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-091919_47_091919.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-091919_48_091919.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-091919_86_091919.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-092525_59_092525.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-093131_68_093131.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-093131_72_093131.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-093131_78_093131.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-093131_99_093131.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-094342_3_094342.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-094342_6_094342.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-094948_15_094948.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-095553_21_095553.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-095553_9_095553.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-100805_12_100805.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-100805_29_100805.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-100805_43_100805.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-100805_44_100805.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-100805_50_100805.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-100805_54_100805.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-100805_99_100805.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-101411_20_101411.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-102016_64_102016.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-102622_69_102622.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-102622_71_102622.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-103228_81_103228.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-103228_85_103228.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-103228_93_103228.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-103834_100_103834.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-104440_13_104440.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-104440_29_104440.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-104440_58_104440.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-104440_7_104440.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-104440_99_104440.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-105045_16_105045.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-105045_19_105045.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-105651_24_105651.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-110257_23_110257.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-110257_71_110257.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-110903_45_110903.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-112114_56_112114.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-112114_61_112114.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-112114_62_112114.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-112114_63_112114.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-112114_72_112114.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-112114_73_112114.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-112719_78_112719.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-112719_87_112719.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-113325_16_113325.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-113325_92_113325.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-113930_1_113930.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-114537_22_114537.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-115142_25_115142.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-115142_28_115142.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-115142_34_115142.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-115748_38_115748.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-120354_36_120354.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-120354_41_120354.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-121605_53_121605.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-121605_65_121605.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-121605_67_121605.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-122211_75_122211.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-122211_76_122211.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-122211_96_122211.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-124633_49_124633.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-125239_3_125239.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-125239_66_125239.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-125844_14_125844.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-125844_19_125844.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-125844_74_125844.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-130450_24_130450.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-130450_53_130450.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-131055_23_131055.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-132306_35_132306.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-132306_37_132306.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-132306_38_132306.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-132306_74_132306.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-132306_98_132306.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-133517_25_133517.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-133517_46_133517.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-133517_52_133517.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-134122_57_134122.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-134122_59_134122.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-134122_61_134122.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-134728_45_134728.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-134728_70_134728.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-135334_47_135334.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-135940_23_135940.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-135940_80_135940.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-140545_71_140545.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-140545_90_140545.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-140545_91_140545.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-141151_94_141151.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-141151_97_141151.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-142403_44_142403.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-142403_45_142403.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-143008_15_143008.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-143008_6_143008.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-144425_47_144425.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-144425_90_144425.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-144425_9_144425.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-145031_26_145031.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-145031_81_145031.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-145635_33_145635.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-150241_25_150241.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-150241_37_150241.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-150241_39_150241.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-150241_40_150241.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-150241_97_150241.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-150846_43_150846.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-151451_38_151451.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-151451_62_151451.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-152057_49_152057.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-152057_68_152057.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-152702_1_152702.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-152702_69_152702.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-153503_15_153503.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-153503_35_153503.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-153503_82_153503.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-153503_96_153503.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-154108_19_154108.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-154108_20_154108.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-154108_85_154108.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-154714_26_154714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-154714_31_154714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-154714_33_154714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-155320_41_155320.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-155320_48_155320.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-155320_53_155320.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-155925_16_155925.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-155925_17_155925.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-155925_28_155925.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-155925_3_155925.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-155925_56_155925.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-155925_67_155925.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-160531_1_160531.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-160531_84_160531.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-161742_14_161742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-161742_15_161742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-161742_27_161742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-161742_85_161742.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-162954_1_162954.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-162954_43_162954.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-163600_3_163600.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-163600_72_163600.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-164206_88_164206.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-164206_93_164206.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-164206_99_164206.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-164812_20_164812.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-164812_23_164812.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-165417_29_165417.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-165417_32_165417.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-170022_42_170022.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-170629_53_170629.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-170629_56_170629.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-171234_10_171234.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-171234_86_171234.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-171840_7_171840.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-171840_8_171840.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-172446_15_172446.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-173052_33_173052.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-173052_36_173052.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-173052_99_173052.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-173658_37_173658.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-173658_45_173658.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-173658_92_173658.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-174910_72_174910.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-175516_95_175516.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-175516_97_175516.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-182545_10_182545.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-182545_31_182545.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-182545_54_182545.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-183150_22_183150.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-183150_46_183150.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-183150_47_183150.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-183150_48_183150.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-183150_57_183150.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-184402_1_184402.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-184402_4_184402.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-184402_92_184402.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-185008_13_185008.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-185613_36_185613.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-190219_52_190219.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-190219_64_190219.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-190825_3_190825.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-191432_26_191432.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-192038_96_192038.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193250_50_193250.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193250_56_193250.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193250_57_193250.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193250_58_193250.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193250_62_193250.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193250_65_193250.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193854_18_193854.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193854_25_193854.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193854_6_193854.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-193854_88_193854.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-194500_84_194500.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-194500_9_194500.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-195107_100_195107.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-195107_30_195107.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-195107_31_195107.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-195107_32_195107.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-195714_39_195714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-195714_91_195714.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-200925_81_200925.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-203348_34_203348.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-203348_97_203348.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-203954_42_203954.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-203954_50_203954.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-204600_74_204600.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-204600_92_204600.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-205205_11_205205.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-205811_16_205811.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-210417_26_210417.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-210417_31_210417.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-210417_5_210417.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-211022_68_211022.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-211628_11_211628.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-211628_13_211628.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-211628_3_211628.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-212234_83_212234.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-212840_14_212840.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-213445_30_213445.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-214051_31_214051.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-214051_61_214051.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-214657_6_214657.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-214657_82_214657.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-214657_90_214657.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-215303_51_215303.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-215908_18_215908.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-220515_26_220515.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-221121_16_221121.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-221121_36_221121.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-221121_43_221121.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-222332_65_222332.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-222332_67_222332.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-222332_68_222332.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-222332_74_222332.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-222938_39_222938.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-224149_12_224149.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-224756_23_224756.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-224756_99_224756.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-225402_13_225402.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-225402_33_225402.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-230009_45_230009.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-230009_52_230009.csv
# 資料長度不足，跳過 H:\cell_data_processed\cells\20210722-233844_87_233844.csv
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# ...
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 預測資料長度: 167, 真實資料長度: 167
# {0: [(array([-0.02148824, -0.0218474 ], dtype=float32), array([-0.01229834, -0.00659918], dtype=float32)), (array([-0.02137462, -0.0217388 ], dtype=float32), array([-0.01238009, -0.0066264 ], dtype=float32)), (array([-0.02134779, -0.02167378], dtype=float32), array([-0.01211826, -0.00633559], dtype=float32)), (array([-0.02045283, -0.02075696], dtype=float32), array([-0.00827808, -0.0027626 ], dtype=float32))], 1: [(array([-0.03103841, -0.0307586 ], dtype=float32), array([-0.01149365, -0.00512457], dtype=float32)), (array([-0.03339444, -0.03300679], dtype=float32), array([-0.00817974, -0.00173978], dtype=float32)), (array([-0.03263587, -0.03227694], dtype=float32), array([-0.00703564, -0.00074785], dtype=float32)), (array([-0.03088541, -0.03060132], dtype=float32), array([-0.00806096, -0.00194434], dtype=float32)), (array([-0.02812589, -0.02803721], dtype=float32), array([-0.00980959, -0.00387992], dtype=float32)), (array([-0.02627431, -0.02634887], dtype=float32), array([-0.01023648, -0.00436895], dtype=float32)), (array([-0.02458243, -0.02473295], dtype=float32), array([-0.00844709, -0.00276698], dtype=float32))], 2: [(array([-0.02545719, -0.02569197], dtype=float32), array([-0.01415158, -0.00809368], dtype=float32)), (array([-0.02456978, -0.02487898], dtype=float32), array([-0.01670735, -0.01053376], dtype=float32)), (array([-0.02250957, -0.02293338], dtype=float32), array([-0.01823143, -0.01210343], dtype=float32)), (array([-0.02223027, -0.02267154], dtype=float32), array([-0.01882317, -0.01268268], dtype=float32)), (array([-0.02293468, -0.02333293], dtype=float32), array([-0.01911998, -0.01288768], dtype=float32)), (array([-0.02303723, -0.02339229], dtype=float32), array([-0.01721179, -0.01108677], dtype=float32)), (array([-0.0237912 , -0.02408183], dtype=float32), array([-0.01560593, -0.00954411], dtype=float32)), (array([-0.02513233, -0.02532922], dtype=float32), array([-0.01371491, -0.00771673], dtype=float32)), (array([-0.0253008, -0.0254611], dtype=float32), array([-0.01201791, -0.00610348], dtype=float32))], 3: [(array([-0.03462078, -0.03405416], dtype=float32), array([-0.00785187, -0.00119905], dtype=float32)), (array([-0.03561267, -0.0349378 ], dtype=float32), array([-0.00874099, -0.00188397], dtype=float32)), (array([-0.0345259 , -0.03402214], dtype=float32), array([-0.00950833, -0.00282019], dtype=float32)), (array([-0.03228617, -0.03191455], dtype=float32), array([-0.01102918, -0.00454669], dtype=float32)), (array([-0.03081201, -0.03053489], dtype=float32), array([-0.01096289, -0.00464531], dtype=float32))], 4: [(array([-0.02938043, -0.02929752], dtype=float32), array([-0.01499796, -0.00862641], dtype=float32)), (array([-0.02753321, -0.02757584], dtype=float32), array([-0.0138051, -0.0076785], dtype=float32)), (array([-0.02779365, -0.02785282], dtype=float32), array([-0.01437787, -0.00820493], dtype=float32)), (array([-0.02575032, -0.02594534], dtype=float32), array([-0.01366984, -0.0076394 ], dtype=float32)), (array([-0.02441904, -0.02469452], dtype=float32), array([-0.01455617, -0.00854844], dtype=float32)), (array([-0.02358659, -0.02393424], dtype=float32), array([-0.01624069, -0.01017545], dtype=float32)), (array([-0.02329301, -0.02365195], dtype=float32), array([-0.0166273 , -0.01054632], dtype=float32)), (array([-0.02304034, -0.02340653], dtype=float32), array([-0.01741789, -0.01129322], dtype=float32))], 5: [(array([-0.02563893, -0.025619  ], dtype=float32), array([-0.00521122,  0.00039416], dtype=float32)), (array([-0.025795  , -0.02571348], dtype=float32), array([-0.0025088 ,  0.00297256], dtype=float32))], 6: [(array([-0.0292241 , -0.02909219], dtype=float32), array([-0.00647569, -0.0006166 ], dtype=float32)), (array([-0.03254741, -0.03222557], dtype=float32), array([-0.00645947, -0.00019241], dtype=float32)), (array([-0.03270087, -0.03233748], dtype=float32), array([-0.00417932,  0.00202784], dtype=float32)), (array([-0.03380028, -0.03334533], dtype=float32), array([-0.00144984,  0.00475485], dtype=fl ...
# {0: [(array([-0.058912, -0.039156], dtype=float32), array([-0.034027, -0.025673], dtype=float32)), (array([-0.039156, -0.0306  ], dtype=float32), array([-0.025673, -0.01918 ], dtype=float32)), (array([-0.0306  , -0.051927], dtype=float32), array([-0.01918 , -0.027878], dtype=float32)), (array([-0.051927, -0.042168], dtype=float32), array([-0.027878, -0.020119], dtype=float32))], 1: [(array([-0.051704, -0.045233], dtype=float32), array([-0.022744, -0.033386], dtype=float32)), (array([-0.045233, -0.039949], dtype=float32), array([-0.033386, -0.02465 ], dtype=float32)), (array([-0.039949, -0.038893], dtype=float32), array([-0.02465 , -0.024811], dtype=float32)), (array([-0.038893, -0.040657], dtype=float32), array([-0.024811, -0.023003], dtype=float32)), (array([-0.040657, -0.03504 ], dtype=float32), array([-0.023003, -0.022941], dtype=float32)), (array([-0.03504 , -0.041247], dtype=float32), array([-0.022941, -0.026314], dtype=float32)), (array([-0.041247, -0.037864], dtype=float32), array([-0.026314, -0.016548], dtype=float32))], 2: [(array([-0.034228, -0.036573], dtype=float32), array([-0.040802, -0.041237], dtype=float32)), (array([-0.036573, -0.034397], dtype=float32), array([-0.041237, -0.040329], dtype=float32)), (array([-0.034397, -0.039362], dtype=float32), array([-0.040329, -0.036644], dtype=float32)), (array([-0.039362, -0.033314], dtype=float32), array([-0.036644, -0.027549], dtype=float32)), (array([-0.033314, -0.044042], dtype=float32), array([-0.027549, -0.033486], dtype=float32)), (array([-0.044042, -0.040141], dtype=float32), array([-0.033486, -0.027809], dtype=float32)), (array([-0.040141, -0.039968], dtype=float32), array([-0.027809, -0.026504], dtype=float32)), (array([-0.039968, -0.036329], dtype=float32), array([-0.026504, -0.029091], dtype=float32)), (array([-0.036329, -0.049349], dtype=float32), array([-0.029091, -0.024483], dtype=float32))], 3: [(array([-0.049021, -0.057865], dtype=float32), array([-0.033432, -0.035729], dtype=float32)), (array([-0.057865, -0.04187 ], dtype=float32), array([-0.035729, -0.028831], dtype=float32)), (array([-0.04187 , -0.033379], dtype=float32), array([-0.028831, -0.030922], dtype=float32)), (array([-0.033379, -0.037336], dtype=float32), array([-0.030922, -0.038918], dtype=float32)), (array([-0.037336, -0.039803], dtype=float32), array([-0.038918, -0.020973], dtype=float32))], 4: [(array([-0.038292, -0.039123], dtype=float32), array([-0.028626, -0.034965], dtype=float32)), (array([-0.039123, -0.038311], dtype=float32), array([-0.034965, -0.032684], dtype=float32)), (array([-0.038311, -0.035277], dtype=float32), array([-0.032684, -0.037285], dtype=float32)), (array([-0.035277, -0.031669], dtype=float32), array([-0.037285, -0.03936 ], dtype=float32)), (array([-0.031669, -0.04212 ], dtype=float32), array([-0.03936 , -0.034508], dtype=float32)), (array([-0.04212 , -0.035145], dtype=float32), array([-0.034508, -0.038696], dtype=float32)), (array([-0.035145, -0.042484], dtype=float32), array([-0.038696, -0.033776], dtype=float32)), (array([-0.042484, -0.042075], dtype=float32), array([-0.033776, -0.035507], dtype=float32))], 5: [(array([-0.044521, -0.040184], dtype=float32), array([-0.021118, -0.015007], dtype=float32)), (array([-0.040184, -0.036356], dtype=float32), array([-0.015007, -0.017753], dtype=float32))], 6: [(array([-0.056267, -0.053455], dtype=float32), array([-0.026611, -0.008477], dtype=float32)), (array([-0.053455, -0.050606], dtype=float32), array([-0.008477, -0.015541], dtype=float32)), (array([-0.050606, -0.045713], dtype=float32), array([-0.015541, -0.012367], dtype=float32)), (array([-0.045713, -0.032538], dtype=float32), array([-0.012367, -0.00705 ], dtype=float32)), (array([-0.032538, -0.038942], dtype=float32), array([-0.00705 , -0.011718], dtype=float32)), (array([-0.038942, -0.024698], dtype=float32), array([-0.011718, -0.001076], dtype=float32))], 7: [(array([-0.054802, -0.041689], dtype=float32), array([-0.001564,  0.004631], dtype=float32)), (array([-0.0 ...
# === 經緯度位置（還原後）總體評估 ===
# Latitude MSE: 0.000837 度
# Longitude MSE: 0.001114 度
# Latitude MAE: 0.024776 度
# Longitude MAE: 0.028326 度
# Latitude RMSE: 0.028932
# Longitude RMSE: 0.033370
# Average Haversine distance error: 4.207 km
#
# === 第一步預測 (t+1) 評估 ===
# Latitude MSE: 0.000374 度
# Longitude MSE: 0.000394 度
# Latitude MAE: 0.017120 度
# Longitude MAE: 0.017423 度
# Latitude RMSE: 0.019350
# Longitude RMSE: 0.019848
# Average Haversine distance error: 2.760 km
#
# === 第二步預測 (t+2) 評估 ===
# Latitude MSE: 0.001300 度
# Longitude MSE: 0.001833 度
# Latitude MAE: 0.032432 度
# Longitude MAE: 0.039229 度
# Latitude RMSE: 0.036051
# Longitude RMSE: 0.042815
# Average Haversine distance error: 5.654 km
